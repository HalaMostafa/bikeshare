# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york': 'new_york_city.csv',
              'washington': 'washington.csv' }

def get_filters():

    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    city = input("please entre what city you want to see data for chicago , new york ,or washington ?\n")
    check_city_input=['chicago','new york','washington']
    while city not in check_city_input:
        city=input("please check your spilling,use lowercase letters\n")
    
    
    # TO DO: get user input for month (all, january, february, ... , june)
    time_filter=input("would you like to filter data by month, day, both, or not at all ?type none for no time filter\n")
    check_time_filter_input=["month","day","none","both"]
    while time_filter not in check_time_filter_input:
        time_filter=input("re entre your filter make all letter lowercased")
        
        
        
     
    if time_filter=="month":
        day="none"
        month=input("which month January, February, March, April, May, or June?\n")
        month_list=[ "January", "February", "March", "April", "May", "June"]
        while month not in month_list:
                month=input("make sure that first letter is capitalized\n")
    elif time_filter=="day":
        month="none"
        day=input("which day? Saturday, Sunday, Monday, Tuesday, Wednesday, Thursday, or Friday\n")
        day_list=["Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
        while day not in day_list:
            day=input("make sure that first letter is capitalized\n")
    elif time_filter=="both":
        month=input("which month January, February, March, April, May, or June?\n")
        month_list=[ "January", "February", "March", "April", "May", "June"]
        while month not in month_list:
            month=input("make sure that first letter is capitalized\n")
        day=input("which day? Saturday, Sunday, Monday, Tuesday, Wednesday, Thursday, or Friday\n")
        day_list=["Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
        while day not in day_list:
            day=input("make sure that first letter is capitalized\n")
    else:
        day="none"
        month="none" 


    print('-'*40)
    return city, month, day

# %%
def load_data(city, month, day):
    #load data for specified city
    df=pd.read_csv(CITY_DATA[city])
   
     # convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day'] = df['Start Time'].dt.day
    df['hour']= df['Start Time'].dt.hour
    df['week_day'] = df['Start Time'].dt.weekday

    # filter by month if applicable
    if day=='none'and month!='none':
        # use the index of the months list to get the corresponding int
        months = ['January', 'February', 'March', 'April', 'May', 'June']
        month = months.index(month) + 1
        # filter by month to create the new dataframe
        df = df[df['month'] == month ]
    # filter by day of week if applicable
    elif month == 'none'and day!='none':
        # filter by day of week to create the new dataframe
        week_days = [ "Monday", "Tuesday", "Wednesday", "Thursday", "Friday","Saturday", "Sunday"]
        day = week_days.index(day) 
        df = df[df['week_day'] == day]
    elif month != 'none'and day!='none':
        # use the index of the months list to get the corresponding int
        months = ['January', 'February', 'March', 'April', 'May', 'June']
        month = months.index(month) + 1
         # filter by day of week to create the new dataframe
        week_days = [ "Monday", "Tuesday", "Wednesday", "Thursday", "Friday","Saturday", "Sunday"]
        day = week_days.index(day) 
        df = df[df['week_day'] == day]
        # filter by month to create the new dataframe
        df = df[(df['month'] == month) & (df['week_day'] == day) ]

    return df

# %%
#1 Popular times of travel
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""
    df.head()

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    print("most common month:\n")
    print(df['month'].mode())


    # TO DO: display the most common day of week
    print("most common day:\n")
    print(df['day'].mode())


    # TO DO: display the most common start hour
    mode_value= df['hour'].mode()
    if(mode_value.empty == True):
        ans= 'None'
    else:
        ans= mode_value[0]
    print("most common start hour:\n")
    print(ans)


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
#2 Popular stations and trip
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    print("most commonly used start station:\n")
    print(df['Start Station'].mode())


    # TO DO: display most commonly used end station
    print("most commonly used end station:\n")
    print(df['End Station'].mode())


    # TO DO: display most frequent combination of start station and end station trip
    print("most frequent combination of start station and end station trip:\n")
    df['start+end']= df['Start Station']+ '+'+ df['End Station']
    print(df['start+end'].mode())


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
#3 Trip duration
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    print("total travel time:\n")
    print(df['Trip Duration'].sum())


    # TO DO: display mean travel time
    print("mean travel time:\n")
    print(df['Trip Duration'].sum())


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def user_stats(df,city):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    print("counts of user types:\n")
    print(df["User Type"].value_counts())


    # TO DO: Display counts of gender
    if city=='chicago' or city=='new york':
        print("counts of gender:\n")
        print(df["Gender"].value_counts())


    # TO DO: Display earliest, most recent, and most common year of birth
    if city=='chicago' or city=='new york':
        print("earliest year of birth is:\n")
        print(df["Birth Year"].min())
        print("most recent year of birth is::\n")
        print(df["Birth Year"].max())
        print("most common year of birth is\n")
        print(df["Birth Year"].mode())
    


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df,city)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
# please entre what city you want to see data for chicago , new york ,or washington ?
# chicago
# would you like to filter data by month, day, both, or not at all ?type none for no time filter
# both
# which month January, February, March, April, May, or June?
# January
# which day? Saturday, Sunday, Monday, Tuesday, Wednesday, Thursday, or Friday
# Saturday
# ----------------------------------------
#
# Calculating The Most Frequent Times of Travel...
#
# most common month:
#
# 0    1
# dtype: int64
# most common day:
#
# 0    21
# dtype: int64
# most common start hour:
#
# 13
#
# This took 0.002988100051879883 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# most commonly used start station:
#
# 0    Streeter Dr & Grand Ave
# dtype: object
# most commonly used end station:
#
# 0    Streeter Dr & Grand Ave
# dtype: object
# ...
